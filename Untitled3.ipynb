# %%
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from math import sqrt
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
#path=os.getcwd()
#file=open("attributes.csv",'a')
dateparse= lambda x:pd.datetime.strptime(x,'%d-%m-%Y')
df=pd.read_csv("sample.csv",parse_dates=['Date'],date_parser=dateparse)
df.head()
df1=pd.read_csv("test.csv",parse_dates=['Date'],date_parser=dateparse)
df1.head()
for i in range(1,4):
    print(i)
    x=str(i)
    aa=df[df.Productcat=="ProdCat"+x]
    l=aa.values
    train=l[:,1:3]
    bb=df1[df1.Productcat=="ProdCat"+x]
    l1=bb.values
    valid=l1[:,1:3]
    training=l[:,2]
    validation=l1[:,2]
    count=valid.shape
    model = auto_arima(training, start_p=1, start_q=1,max_p=3, max_q=3, m=12,start_P=0, seasonal=True,d=1, D=1, trace=True,error_action='ignore',suppress_warnings=True)
    model.fit(training)
    forecast = model.predict(n_periods=count[0])
    forecast = pd.DataFrame(forecast,index = bb.index,columns=['Prediction'])
    #rms=np.sqrt(np.mean(np.power((np.array(validation)-np.array(forecast['Prediction'])),2)))
    rmse=sqrt(mean_squared_error(validation,forecast['Prediction']))
    r2=r2_score(validation,forecast['Prediction'])
    mae=mean_absolute_error(validation,forecast['Prediction'])
    #file.write(str("ProdCat19"))
    #file.write(",")
    #file.write(str(rmse))
    #file.write(",")
    #file.write(str(r2))
    #file.write(",")
    #file.write(str(mae))
    #file.write("\n")
#file.close()
    plt.plot(l[:,1],l[:,2])
    plt.plot(l1[:,1],l1[:,2])
    plt.plot(l1[:,1],forecast['Prediction'])
    #plt.plot(forecast['Prediction'])
    plt.show()
# Out:
# 1
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2247.937, BIC=2263.155, Fit time=0.654 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=2445.674, BIC=2451.761, Fit time=0.016 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=2350.902, BIC=2363.076, Fit time=0.662 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2246.667, BIC=2258.841, Fit time=0.894 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2247.724, BIC=2262.941, Fit time=0.694 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=2327.132, BIC=2336.262, Fit time=0.078 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2247.576, BIC=2262.794, Fit time=1.751 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2250.587, BIC=2268.848, Fit time=3.940 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=2354.124, BIC=2363.254, Fit time=0.400 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2247.876, BIC=2263.093, Fit time=0.698 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2250.667, BIC=2268.927, Fit time=0.962 seconds
# Total fit time: 10.765 seconds
# 2
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2227.745, BIC=2242.962, Fit time=1.253 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=2424.404, BIC=2430.491, Fit time=0.047 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=2334.190, BIC=2346.363, Fit time=0.665 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2225.868, BIC=2238.041, Fit time=0.831 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2226.529, BIC=2241.746, Fit time=0.722 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=2315.357, BIC=2324.487, Fit time=0.109 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2225.386, BIC=2240.603, Fit time=1.793 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2227.315, BIC=2245.575, Fit time=2.558 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=2325.910, BIC=2338.084, Fit time=2.206 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=2227.297, BIC=2245.558, Fit time=2.534 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=2229.382, BIC=2250.686, Fit time=3.066 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Total fit time: 15.795 seconds
# 3
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1793.479, BIC=1808.697, Fit time=0.737 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=1933.090, BIC=1939.177, Fit time=0.017 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1858.375, BIC=1870.549, Fit time=0.366 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1802.655, BIC=1814.829, Fit time=0.435 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1793.953, BIC=1812.213, Fit time=0.732 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=1867.051, BIC=1879.225, Fit time=0.187 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1795.523, BIC=1816.827, Fit time=3.719 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1832.793, BIC=1844.966, Fit time=0.675 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1795.481, BIC=1813.742, Fit time=0.738 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1852.080, BIC=1861.210, Fit time=0.407 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1796.163, BIC=1817.467, Fit time=1.599 seconds
# Total fit time: 9.636 seconds
