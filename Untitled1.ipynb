# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
# load dataset
def parser(x):
    #print(x)
    for i in x[1:]:
        print(i[:10])
        #return datetime.strptime(str(i[:10]), "%d-%m-%Y")
	#return datetime.strptime(x, format='%d-%m-%Y')
#series = read_csv('trenddata.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
series= read_csv("trenddata.csv", sep=',', names=['Date', 'Sales'])
# summarize first few rows
print(series.head())
# line plot
series.plot()
pyplot.show()'''
# Out:
#          Date  Sales
# 0        Date  Sales
# 1  13-06-2013    802
# 2  14-06-2013    671
# 3  15-06-2013    866
# 4  18-06-2013    602
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-be9b7c3616f1> in <module>
#      14 print(series.head())
#      15 # line plot
# ---> 16 series.plot()
#      17 pyplot.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
# ...

# %%
import pandas as pd
from matplotlib import pyplot as pl
df=pd.read_csv("sample.csv")
df.head()
aa=df[df.Productcat=="ProdCat1"]
plt.plot(aa.Date,aa.Sales)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
dateparse= lambda x:pd.datetime.strptime(x,'%d-%m-%Y')
df=pd.read_csv("sample.csv",parse_dates=['Date'],date_parser=dateparse)
df.head()
aa=df[df.Productcat=="ProdCat1"]
plt.plot(aa.Date,aa.Sales)
plt.show()
print(aa.Date[1][])
print(aa.Sales)
# Out:
# 2013-06-14 00:00:00
# 0       802
# 1       671
# 2       866
# 3       602
# 4       343
# 5       377
# 6       636
# 7      1082
# 8       888
# 9       486
# 10      930
# 11     1008
# 12     2106
# 13      644
# 14      547
# 15      920
# 16      689
# 17      664
# 18      724
# 19      300
# 20      439
# 21     1238
# 22      831
# 23      950
# 24      937
# 25      590
# 26      668
# 27      543
# 28      589
# 29      614
#        ...
# 138     833
# 139     576
# 140     672
# 141     593
# 142     901
# 143     729
# 144     698
# 145     597
# 146     729
# 147    1160
# 148     774
# 149     655
# 150     684
# 151    1258
# 152      53
# 153     819
# 154     826
# 155     738
# 156     711
# 157     801
# 158     793
# 159     705
# 160     868
# 161     811
# 162     733
# 163      40
# 164     818
# 165     779
# 166     800
# 167    1115
# Name: Sales, Length: 168, dtype: int64
